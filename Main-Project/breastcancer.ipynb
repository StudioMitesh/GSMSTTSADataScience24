# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rf = pd.read_csv("riskfactors.csv")
rf
# Out:
#         year  age_group_5_years  race_eth  first_degree_hx  age_menarche  \
# 0       2013                  7         1                0             9
# 1       2013                  7         1                0             9
# 2       2013                  7         1                0             9
# 3       2013                  7         1                0             9
# 4       2013                  7         1                0             9
# ...      ...                ...       ...              ...           ...
# 509405  2017                 13         9                9             9
# 509406  2017                 13         9                9             9
# 509407  2017                 13         9                9             9
# 509408  2017                 13         9                9             9
# 509409  2017                 13         9                9             9
#
#         age_first_birth  BIRADS_breast_density  current_hrt  menopaus  \
# 0                     3                      1            1         2
# 1                     3                      1            1         2
# 2                     3                      1            1         2
# 3                     3                      1            1         2
# 4                     3                      1            1         2
# ...                 ...                    ...          ...       ...
# 509405                9                      1            9         2
# 509406                9                      2            0         2
# 509407                9                      2            9         2
# 509408                9                      3            0         2
# 509409                9                      3            9         2
#
#         bmi_group  biophx  breast_cancer_history  count
# 0               3       0                      0      7
# 1               3       1                      0      3
# 2               4       0                      0      6
# 3               4       1                      0      1
# 4               4       1                      1      1
# ...           ...     ...                    ...    ...
# 509405          9       1                      0      1
# 509406          9       0                      0      1
# 509407          9       9                      9      1
# 509408          9       0                      0      1
# 509409          9       9                      0      1
#
# [509410 rows x 13 columns]

# %%
rf.replace(9, np.nan, inplace=True)

# %%
rf.fillna(rf.mean(), inplace=True)

# %%
rf= rf.astype(int)

# %%
rf
# Out:
#         year  age_group_5_years  race_eth  first_degree_hx  age_menarche  \
# 0       2013                  7         1                0             0
# 1       2013                  7         1                0             0
# 2       2013                  7         1                0             0
# 3       2013                  7         1                0             0
# 4       2013                  7         1                0             0
# ...      ...                ...       ...              ...           ...
# 509405  2017                 13         2                0             0
# 509406  2017                 13         2                0             0
# 509407  2017                 13         2                0             0
# 509408  2017                 13         2                0             0
# 509409  2017                 13         2                0             0
#
#         age_first_birth  BIRADS_breast_density  current_hrt  menopaus  \
# 0                     3                      1            1         2
# 1                     3                      1            1         2
# 2                     3                      1            1         2
# 3                     3                      1            1         2
# 4                     3                      1            1         2
# ...                 ...                    ...          ...       ...
# 509405                1                      1            0         2
# 509406                1                      2            0         2
# 509407                1                      2            0         2
# 509408                1                      3            0         2
# 509409                1                      3            0         2
#
#         bmi_group  biophx  breast_cancer_history  count
# 0               3       0                      0      7
# 1               3       1                      0      3
# 2               4       0                      0      6
# 3               4       1                      0      1
# 4               4       1                      1      1
# ...           ...     ...                    ...    ...
# 509405          2       1                      0      1
# 509406          2       0                      0      1
# 509407          2       0                      0      1
# 509408          2       0                      0      1
# 509409          2       0                      0      1
#
# [509410 rows x 13 columns]

# %%
labels = ["White", "Black", "Asian", "Native American", "Hispanic", "Other"]

plt.figure(figsize=(8, 6))
sns.countplot(x='race_eth', data=rf, palette='viridis')
plt.title('Count of each race/ethnicity in set')
plt.xticks(ticks=range(len(labels)), labels=labels)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="year", data=rf, palette="inferno")

# Adding labels and title
plt.title('Bar Plot for Count Over Time')
plt.xlabel('Year')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='bmi_group', data=rf)


# Adding labels and title
plt.title('Bar Plot for Count of each BMI Group')
plt.xlabel('BMI Group')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
sns.displot(rf, x="bmi_group", col="menopaus", row="breast_cancer_history", binwidth=0.75, height=3, facet_kws=dict(margin_titles=True))
# Out:
# c:\Users\mites\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(y='age_group_5_years', x='breast_cancer_history', data=rf)
# Out:
# <Axes: xlabel='breast_cancer_history', ylabel='age_group_5_years'>

# %%
sns.violinplot(y='current_hrt', x='breast_cancer_history', data=rf)
# Out:
# <Axes: xlabel='breast_cancer_history', ylabel='current_hrt'>

# %%
sns.displot(rf, x="race_eth", col="age_menarche", row="breast_cancer_history", binwidth=3, height=3, facet_kws=dict(margin_titles=True))
# Out:
# c:\Users\mites\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corr_matrix = rf.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a261b_row0_col0, #T_a261b_row1_col1, #T_a261b_row2_col2, #T_a261b_row3_col3, #T_a261b_row4_col4, #T_a261b_row5_col5, #T_a261b_row6_col6, #T_a261b_row7_col7, #T_a261b_row8_col8, #T_a261b_row9_col9, #T_a261b_row10_col10, #T_a261b_row11_col11, #T_a261b_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col1, #T_a261b_row1_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col2, #T_a261b_row0_col5, #T_a261b_row1_col4, #T_a261b_row3_col6, #T_a261b_row3_col7, #T_a261b_row4_col6, #T_a261b_row5_col0, #T_a261b_row5_col10, #T_a261b_row5_col12, #T_a261b_row6_col11, #T_a261b_row8_col4, #T_a261b_row9_col2, #T_a261b_row11_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col3, #T_a261b_row2_col9, #T_a261b_row3_col8, #T_a261b_row7_col0, #T_a261b_row7_col5, #T_a261b_row10_col5, #T_a261b_row11_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col4, #T_a261b_row3_col4, #T_a261b_row3_col5, #T_a261b_row3_col9, #T_a261b_row4_col0, #T_a261b_row4_col1, #T_a261b_row4_col3, #T_a261b_row4_col8, #T_a261b_row4_col10, #T_a261b_row4_col11, #T_a261b_row5_col3, #T_a261b_row5_col11, #T_a261b_row6_col2, #T_a261b_row6_col3, #T_a261b_row6_col4, #T_a261b_row6_col7, #T_a261b_row6_col12, #T_a261b_row7_col3, #T_a261b_row7_col6, #T_a261b_row7_col10, #T_a261b_row9_col3, #T_a261b_row12_col0, #T_a261b_row12_col1, #T_a261b_row12_col5, #T_a261b_row12_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col6, #T_a261b_row5_col1, #T_a261b_row8_col11, #T_a261b_row10_col6, #T_a261b_row11_col8, #T_a261b_row12_col4, #T_a261b_row12_col9 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col7, #T_a261b_row0_col9, #T_a261b_row5_col7, #T_a261b_row8_col3, #T_a261b_row9_col8, #T_a261b_row9_col10, #T_a261b_row9_col11, #T_a261b_row10_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col8, #T_a261b_row3_col1, #T_a261b_row4_col12, #T_a261b_row5_col9, #T_a261b_row9_col5, #T_a261b_row9_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col10, #T_a261b_row2_col4, #T_a261b_row7_col11, #T_a261b_row9_col0, #T_a261b_row11_col3, #T_a261b_row11_col6, #T_a261b_row12_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_a261b_row0_col11, #T_a261b_row0_col12, #T_a261b_row1_col12, #T_a261b_row2_col0, #T_a261b_row2_col6, #T_a261b_row3_col0, #T_a261b_row3_col11, #T_a261b_row4_col2, #T_a261b_row10_col4, #T_a261b_row10_col7, #T_a261b_row11_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col2, #T_a261b_row2_col1, #T_a261b_row2_col7, #T_a261b_row6_col8, #T_a261b_row7_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col3, #T_a261b_row1_col5, #T_a261b_row7_col9, #T_a261b_row8_col0, #T_a261b_row8_col2, #T_a261b_row12_col11 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col7, #T_a261b_row1_col9, #T_a261b_row6_col0, #T_a261b_row8_col10, #T_a261b_row10_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col8, #T_a261b_row8_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_a261b_row1_col10, #T_a261b_row2_col3, #T_a261b_row2_col12, #T_a261b_row4_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a261b_row1_col11, #T_a261b_row11_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a261b_row2_col5, #T_a261b_row3_col10, #T_a261b_row6_col10, #T_a261b_row7_col1, #T_a261b_row8_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a261b_row2_col8, #T_a261b_row9_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_a261b_row2_col10, #T_a261b_row3_col12, #T_a261b_row10_col2, #T_a261b_row10_col12, #T_a261b_row11_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_a261b_row2_col11, #T_a261b_row6_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_a261b_row3_col2, #T_a261b_row7_col4, #T_a261b_row8_col6, #T_a261b_row8_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_a261b_row4_col5, #T_a261b_row5_col2, #T_a261b_row5_col4, #T_a261b_row8_col9, #T_a261b_row8_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_a261b_row4_col9, #T_a261b_row9_col4, #T_a261b_row11_col12, #T_a261b_row12_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a261b_row5_col6, #T_a261b_row7_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_a261b_row5_col8, #T_a261b_row7_col12, #T_a261b_row10_col9, #T_a261b_row11_col7, #T_a261b_row11_col9, #T_a261b_row12_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a261b_row6_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a261b_row6_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a261b_row9_col1, #T_a261b_row10_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a261b_row9_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a261b_row10_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a261b_row10_col11, #T_a261b_row11_col10 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a261b_row12_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a261b_row12_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a261b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a261b_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_a261b_level0_col1" class="col_heading level0 col1" >age_group_5_years</th>
#       <th id="T_a261b_level0_col2" class="col_heading level0 col2" >race_eth</th>
#       <th id="T_a261b_level0_col3" class="col_heading level0 col3" >first_degree_hx</th>
#       <th id="T_a261b_level0_col4" class="col_heading level0 col4" >age_menarche</th>
#       <th id="T_a261b_level0_col5" class="col_heading level0 col5" >age_first_birth</th>
#       <th id="T_a261b_level0_col6" class="col_heading level0 col6" >BIRADS_breast_density</th>
#       <th id="T_a261b_level0_col7" class="col_heading level0 col7" >current_hrt</th>
#       <th id="T_a261b_level0_col8" class="col_heading level0 col8" >menopaus</th>
#       <th id="T_a261b_level0_col9" class="col_heading level0 col9" >bmi_group</th>
#       <th id="T_a261b_level0_col10" class="col_heading level0 col10" >biophx</th>
#       <th id="T_a261b_level0_col11" class="col_heading level0 col11" >breast_cancer_history</th>
#       <th id="T_a261b_level0_col12" class="col_heading level0 col12" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a261b_level0_row0" class="row_heading level0 row0" >year</th>
#       <td id="T_a261b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a261b_row0_col1" class="data row0 col1" >0.137560</td>
#       <td id="T_a261b_row0_col2" class="data row0 col2" >0.018572</td>
#       <td id="T_a261b_row0_col3" class="data row0 col3" >0.016305</td>
#       <td id="T_a261b_row0_col4" class="data row0 col4" >0.007352</td>
#       <td id="T_a261b_row0_col5" class="data row0 col5" >0.011809</td>
#       <td id="T_a261b_row0_col6" class="data row0 col6" >0.046192</td>
#       <td id="T_a261b_row0_col7" class="data row0 col7" >0.020721</td>
#       <td id="T_a261b_row0_col8" class="data row0 col8" >0.057767</td>
#       <td id="T_a261b_row0_col9" class="data row0 col9" >0.026455</td>
#       <td id="T_a261b_row0_col10" class="data row0 col10" >0.026948</td>
#       <td id="T_a261b_row0_col11" class="data row0 col11" >0.021481</td>
#       <td id="T_a261b_row0_col12" class="data row0 col12" >0.009604</td>
#     </tr>
#     <tr>
#       <th id="T_a261b_level0_row1" class="row_heading level0 row1" >age_group_5_years</th>
#       <td id="T_a261b_row1_col0" class="data row1 col0" >0.137560</td>
#       <td id="T_a261b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a261b_row1_col2" class="data row1 col2" >0.098029</td>
#       <td id="T_a261b_row1_col3" class="data row1 col3" >0.056632</td>
#       <td id="T_a261b_row1_col4" class="data row1 col4" >0.009264</td>
#       <td id="T_a261b_row1_col5" class="data row1 col5" >0.055238</td>
#       <td id="T_a261b_

# %%
df = pd.read_csv("breastcancerdata.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
df2 = df.drop(columns=["Unnamed: 32", "id"])

# %%
df2['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df2['diagnosis'] = labelencoder.fit_transform(df2['diagnosis'].values)
df2['diagnosis'].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
df2.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# count     569.000000  ...    569.000000     569.000000       569.000000
# mean        0.181162  ...     16.269190      25.677223       107.261213
# std         0.027414  ...      4.833242       6.146258        33.602542
# min         0.106000  ...      7.930000      12.020000        50.410000
# 25%         0.161900  ...     13.010000      21.080000        84.110000
# 50%         0.179200  ...     14.970000      25.410000        97.660000
# 75%         0.195700  ...     18.790000      29.720000       125.400000
# max         0.304000  ...     36.040000      49.540000       251.200000
#
#         area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# count   569.000000        569.000000         569.000000       569.000000
# mean    880.583128          0.132369           0.254265         0.272188
# std     569.356993          0.022832           0.157336         0.208624
# min     185.200000          0.071170           0.027290         0.000000
# 25%     515.300000          0.116600           0.147200         0.114500
# 50%     686.500000          0.131300           0.211900         0.226700
# 75%    1084.000000          0.146000           0.339100         0.382900
# max    4254.000000          0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
# [8 rows x 31 columns]

# %%
sns.heatmap(df2.isnull(), yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
df2.dtypes
# Out:
# diagnosis                    int32
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
dfmeans = df2.iloc[:,0:11]
dfmeans
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  fractal_dimension_mean
# 0           0.2419                 0.07871
# 1           0.1812                 0.05667
# 2           0.2069                 0.05999
# 3           0.2597                 0.09744
# 4           0.1809                 0.05883
# ..             ...                     ...
# 564         0.1726                 0.05623
# 565         0.1752                 0.05533
# 566         0.1590                 0.05648
# 567         0.2397                 0.07016
# 568         0.1587                 0.05884
#
# [569 rows x 11 columns]

# %%
corr_matrix = dfmeans.corr().abs()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_adecb_row0_col0, #T_adecb_row1_col1, #T_adecb_row1_col3, #T_adecb_row2_col2, #T_adecb_row3_col1, #T_adecb_row3_col3, #T_adecb_row4_col4, #T_adecb_row5_col5, #T_adecb_row6_col6, #T_adecb_row7_col7, #T_adecb_row8_col8, #T_adecb_row9_col9, #T_adecb_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_adecb_row0_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_adecb_row0_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_adecb_row0_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_adecb_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_adecb_row0_col5, #T_adecb_row4_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_adecb_row0_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_adecb_row0_col7 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_adecb_row0_col8 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_adecb_row0_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_adecb_row0_col10, #T_adecb_row2_col5, #T_adecb_row2_col6, #T_adecb_row2_col7, #T_adecb_row2_col9, #T_adecb_row5_col2, #T_adecb_row9_col1, #T_adecb_row9_col3, #T_adecb_row9_col4, #T_adecb_row10_col0, #T_adecb_row10_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_adecb_row1_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_adecb_row1_col2, #T_adecb_row4_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_adecb_row1_col4, #T_adecb_row4_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_adecb_row1_col5, #T_adecb_row2_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_adecb_row1_col6, #T_adecb_row9_col8 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_adecb_row1_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_adecb_row1_col8, #T_adecb_row4_col8 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_adecb_row1_col9 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_adecb_row1_col10 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_adecb_row2_col0, #T_adecb_row6_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_adecb_row2_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_adecb_row2_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_adecb_row2_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_adecb_row2_col10 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_adecb_row3_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_adecb_row3_col2, #T_adecb_row5_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_adecb_row3_col4, #T_adecb_row4_col3 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_adecb_row3_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_adecb_row3_col6, #T_adecb_row6_col1, #T_adecb_row8_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_adecb_row3_col7, #T_adecb_row6_col0 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_adecb_row3_col8 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_adecb_row3_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_adecb_row3_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_adecb_row4_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_adecb_row4_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_adecb_row4_col7, #T_adecb_row9_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_adecb_row4_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_adecb_row4_col10, #T_adecb_row8_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_adecb_row5_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_adecb_row5_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_adecb_row5_col3, #T_adecb_row5_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_adecb_row5_col6 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_adecb_row5_col8, #T_adecb_row7_col9 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_adecb_row5_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_adecb_row5_col10 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_adecb_row6_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_adecb_row6_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_adecb_row6_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_adecb_row6_col7 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_adecb_row6_col8 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_adecb_row6_col9 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_adecb_row6_col10 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_adecb_row7_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_adecb_row7_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_adecb_row7_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_adecb_row7_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_adecb_row7_col4 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_adecb_row7_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_adecb_row7_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_adecb_row7_col8 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_adecb_row7_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_adecb_row8_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_adecb_row8_col1, #T_adecb_row8_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_adecb_row8_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_adecb_row8_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_adecb_row8_col6 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_adecb_row8_col7 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_adecb_row8_col10, #T_adecb_row10_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_adecb_row9_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_adecb_row9_col2, #T_adecb_row10_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_adecb_row9_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_adecb_row9_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_adecb_row9_col10 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_adecb_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_adecb_row10_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_adecb_row10_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_adecb_row10_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_adecb_row10_col6 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_adecb_row10_col9 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# </style>
# <table id="T_adecb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adecb_level0_col0" class="col_heading level0 col0" >diagnosis</th>
#       <th id="T_adecb_level0_col1" class="col_heading level0 col1" >radius_mean</th>
#       <th id="T_adecb_level0_col2" class="col_heading level0 col2" >texture_mean</th>
#       <th id="T_adecb_level0_col3" class="col_heading level0 col3" >perimeter_mean</th>
#       <th id="T_adecb_level0_col4" class="col_heading level0 col4" >area_mean</th>
#       <th id="T_adecb_level0_col5" class="col_heading level0 col5" >smoothness_mean</th>
#       <th id="T_adecb_level0_col6" class="col_heading level0 col6" >compactness_mean</th>
#       <th id="T_adecb_level0_col7" class="col_heading level0 col7" >concavity_mean</th>
#       <th id="T_adecb_level0_col8" class="col_heading level0 col8" >concave points_mean</th>
#       <th id="T_adecb_level0_col9" class="col_heading level0 col9" >symmetry_mean</th>
#       <th id="T_adecb_level0_col10" class="col_heading level0 col10" >fractal_dimension_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adecb_level0_row0" class="row_heading level0 row0" >diagnosis</th>
#       <td id="T_adecb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_adecb_row0_col1" class="data row0 col1" >0.730029</td>
#       <td id="T_adecb_row0_col2" class="data row0 col2" >0.415185</td>
#       <td id="T_adecb_row0_col3" class="data row0 col3" >0.742636</td>
#       <td id="T_adecb_row0_col4" class="data row0 col4" >0.70898

# %%
df2.corrwith(df2['diagnosis']).abs().sort_values(ascending=False)
# Out:
# diagnosis                  1.000000
# concave points_worst       0.793566
# perimeter_worst            0.782914
# concave points_mean        0.776614
# radius_worst               0.776454
# perimeter_mean             0.742636
# area_worst                 0.733825
# radius_mean                0.730029
# area_mean                  0.708984
# concavity_mean             0.696360
# concavity_worst            0.659610
# compactness_mean           0.596534
# compactness_worst          0.590998
# radius_se                  0.567134
# perimeter_se               0.556141
# area_se                    0.548236
# texture_worst              0.456903
# smoothness_worst           0.421465
# symmetry_worst             0.416294
# texture_mean               0.415185
# concave points_se          0.408042
# smoothness_mean            0.358560
# symmetry_mean              0.330499
# fractal_dimension_worst    0.323872
# compactness_se             0.292999
# concavity_se               0.253730
# fractal_dimension_se       0.077972
# smoothness_se              0.067016
# fractal_dimension_mean     0.012838
# texture_se                 0.008303
# symmetry_se                0.006522
# dtype: float64

# %%
X = df2.drop('diagnosis', axis=1).values
y = df2['diagnosis']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=12)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
model = KNeighborsClassifier(n_neighbors = 1)  
model.fit(X_train, y_train)
predicted = model.predict(X_test)

print(confusion_matrix(y_test, predicted))
print("Accuracy (KNN[1]): ", accuracy_score(y_test, predicted.round())*100, "%")
# Out:
# [[104   3]
#  [  6  58]]
# Accuracy (KNN[1]):  94.73684210526315 %

# %%
error_rate = []
  
for i in range(1, 20):
      
    model = KNeighborsClassifier(n_neighbors = i)
    model.fit(X_train, y_train)
    pred_i = model.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.plot(range(1, 20), error_rate, color ='blue',marker ='o',markerfacecolor ='red', markersize =5)
plt.title('Error Rate vs. K Value')
# Out:
# Text(0.5, 1.0, 'Error Rate vs. K Value')

# %%
model = KNeighborsClassifier(n_neighbors = 3)
  
model.fit(X_train, y_train)
predicted = model.predict(X_test)
  
print('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))

print()
print("Accuracy (KNN[5]): ", accuracy_score(y_test, predicted.round())*100, "%")
# Out:
# Confusion Matrix :
# [[106   1]
#  [  6  58]]
#
# Accuracy (KNN[5]):  95.90643274853801 %

# %%
sns.heatmap(confusion_matrix(y_test, predicted), annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=["Benign", "Malignant"],
            yticklabels=["Benign", "Malignant"])
# Out:
# <Axes: >
