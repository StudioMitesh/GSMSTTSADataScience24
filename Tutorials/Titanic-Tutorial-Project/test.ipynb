# %%
import pandas as pd                    
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('titanic_test.csv')

# %%
train.head(100)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..          ...     ...                                                ...
# 95          987       3                         Tenglin, Mr. Gunnar Isidor
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 97          989       3                          Makinen, Mr. Kalle Edvard
# 98          990       3                       Braf, Miss. Elin Ester Maria
# 99          991       3                       Nancarrow, Mr. William Henry
#
# ...

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
train2= pd.read_csv('advertising.csv')

# %%
train2.head(10)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
# 5                     59.99   23     59761.56                226.74
# 6                     88.91   33     53852.85                208.36
# 7                     66.00   48     24593.33                131.76
# 8                     74.53   30     68862.00                221.51
# 9                     69.88   20     55642.32                183.82
#
#                            Ad Topic Line              City  Male     Country  \
# 0     Cloned 5thgeneration orchestration       Wrightburgh     0     Tunisia
# ...

# %%
sns.heatmap(train2.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="Daily Internet Usage",y='Daily Time Spent on Site', data=train2,palette="viridis")
# Out:
# <AxesSubplot:xlabel='Daily Internet Usage', ylabel='Daily Time Spent on Site'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train2.drop('Daily Time Spent on Site',axis=1), 
                                                    train['Age'], test_size=0.40, 
                                                    random_state=101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_412/2649475823.py in <module>
#       1 X_train, X_test, y_train, y_test = train_test_split(train2.drop('Daily Time Spent on Site',axis=1),
#       2                                                     train['Age'], test_size=0.40,
# ----> 3                                                     random_state=101)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     354     """
# ...

# %%
sns.countplot(x="Survived",data=train,palette="viridis", hue="Pclass" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_412/1265770612.py in <module>
# ----> 1 sns.countplot(x="Survived",data=train,palette="viridis", hue="Pclass" )
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3600         estimator, ci, n_boot, units, seed,
#    3601         orient, color, palette, saturation,
# -> 3602         errcolor, errwidth, capsize, dodge
#    3603     )
#    3604
#
# ...

# %%
sns.scatterplot()

# %%
train.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
sns.catplot(data=train, x='Sex', y="Fare")

# %%
sns.scatterplot(data=train, x="Age", y="Area Income", cmap="blue", hue="Pclass")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_412/3152340376.py in <module>
# ----> 1 sns.scatterplot(data=train, x="Age", y="Area Income", cmap="blue", hue="Pclass")
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=20008831-a030-4e89-91a7-5067b0a1728f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
